# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from pprint import pprint

Currframe = pd.read_csv("LagunaSecaLapTimes.csv")

Currframe
# Out:
#                         Name  \
# 0              Acura ARX-01b
# 1    Porsche RS Spyder (Evo)
# 2              Acura ARX-01a
# 3               Audi R10 TDI
# 4          Porsche RS Spyder
# ..                       ...
# 188     Honda NSX (facelift)
# 189  Porsche Boxster S (981)
# 190     Chevrolet Camaro Z28
# 191          Ford Mustang GT
# 192       Kia Soul Sport 2.0
#
#                                                CarLink    Time   PS  Weight_KG
# 0         https://fastestlaps.com/models/acura-arx-01b   70.10  558        825
# 1     https://fastestlaps.com/models/porsche-rs-spyder   70.35  510        775
# 2         https://fastestlaps.com/models/acura-arx-01a   70.91  558        825
# 3          https://fastestlaps.com/models/audi-r10-tdi   71.17  659        925
# 4    https://fastestlaps.com/models/porsche-rs-spyd...   74.03  487        775
# ..                                                 ...     ...  ...        ...
# 188           https://fastestlaps.com/models/honda-nsx  117.00  290       1368
# 189  https://fastestlaps.com/models/porsche-boxster...  119.01  315       1400
# 190  https://fastestlaps.com/models/chevrolet-camar...  125.80  193       1448
# 191  https://fastestlaps.com/models/ford-mustang-gt...  129.90  159       1422
# 192  https://fastestlaps.com/models/kia-soul-sport-2-0  132.67  144       1320
#
# [193 rows x 5 columns]

# %%
additionaldict = {
    "Car_type":[],
    "Year":[],
    "Country_of_Origin": [],
    "Engine_type":[],
    "Displacement": [],
    "Transmission": [],
    "Engine_Layout": [],
    "Drivetrain": []
}

# %%
for index, row in Currframe.iterrows():
    # carName = row["Name"]
    # print(f"Car: {carName}")
    link = row["CarLink"]

    curreq = requests.get(link).text
    soup = BeautifulSoup(curreq)

    colsm6 = soup.find_all("div", class_ = "col-sm-6")

    colsm6col0 = colsm6[0].find_all("div", class_ = "section")

    listtitles = []
    listvalues = []
    toggle = True

    itemtable = colsm6col0[0].find("table")

    for item in itemtable.find_all("tr"):
        for subitem in item.find_all("td"):
            if toggle:
                listtitles.append(subitem.text)
            else:
                listvalues.append(subitem.text)
            toggle = not(toggle)
    
    colsm6col1 = colsm6[1]

    for item in colsm6col1.find_all("div", class_ = "section"):
        targetitem = item.find("h3", id= "powertrainSpecs")
        if targetitem is not None:
            powertrainItem = item
            break
    
    powertitles = []
    powervalues = []
    toggle = True

    for poweritems in powertrainItem.find_all("tr"):
        for subitem in poweritems.find_all("td"):
            if toggle:
                powertitles.append(subitem.text)
            else:
                powervalues.append(subitem.text)
            toggle = not(toggle)

    # Car Type
    if "Car type" in listtitles:
        additionaldict["Car_type"].append(listvalues[listtitles.index("Car type")].strip())
    else:
        additionaldict["Car_type"].append(None)

    # Year
    if "Introduced" in listtitles:
        additionaldict["Year"].append(int(listvalues[listtitles.index("Introduced")]))
    elif "Years built" in listtitles:
        additionaldict["Year"].append(int(listvalues[listtitles.index("Years built")][0:4]))
    else:
        additionaldict["Year"].append(None)

    # Country of Origin
    if "Origin country" in listtitles:
        additionaldict["Country_of_Origin"].append(listvalues[listtitles.index("Origin country")].strip())
    else:
        additionaldict["Country_of_Origin"].append(None)

    # Engine type
    if "Engine type" in powertitles:
        additionaldict["Engine_type"].append(powervalues[powertitles.index("Engine type")].strip())
    else:
        additionaldict["Engine_type"].append(None)

    # Displacement (in liters)
    disp = 0
    if "Displacement" in powertitles:
        disp = powervalues[powertitles.index("Displacement")].split(" ")[0]

    additionaldict["Displacement"].append(float(disp))

    # Transmission
    if "Transmission" in powertitles:
        additionaldict["Transmission"].append(powervalues[powertitles.index("Transmission")].strip())
    else:
        additionaldict["Transmission"].append(None)

    # Splitting up the Layout
    SplitLayout = powervalues[powertitles.index("Layout")].split(",")

    additionaldict["Engine_Layout"].append(SplitLayout[0].strip().lower())

    additionaldict["Drivetrain"].append(SplitLayout[1].strip().lower())

additionaldict
# Out:
# {'Car_type': ['Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Convertible',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   '4-door saloon',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   '4-door saloon',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   '4-door saloon',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   '4-door saloon',
#   'Coupe',
#   '4-door saloon',
#   '4-door saloon',
#   '4-door saloon',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'SUV/truck',
#   'Coupe',
#   '4-door saloon',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Convertible',
#   'Coupe',
#   'SUV/truck',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Estate/wagon',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   '4-door saloon',
#   'Coupe',
#   'SUV/truck',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   '4-door saloon',
#   'Compact',
#   'Coupe',
#   'Coupe',
#   'Open-wheeler',
#   'Convertible',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   '4-door saloon',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   'Coupe',
#   '4-door saloon',
#   'Coupe',
#   'Coupe',
#   '4-door saloon',
#   'Coupe',
#   '4-door saloon',
#   'Compact',
#   '4-door saloon',
#   'Convertible',
#   '4-door saloon',
#   'Coupe',
#   'Compact',
#   'Coupe',
#   'Compact',
#   'Convertible',
#   'Compact',
#   'Coupe',
#   'Convertible',
#   'Convertible',
#   'Convertible',
#   'Compact',
#   'Coupe',
#   'Compact',
#   'Coupe',
#   'Compact',
#   'Coupe',
#   'Convertible',
#   '4-door saloon',
#   'Coupe',
#   'Coupe',
#   'Convertible',
#   'Coupe',
#   'Compact',
#   'Coupe',
#   'Convertible',
#   'Coupe',
#   'Coupe',
#   'Compact'],
#  'Year': [2008,
#   2007,
#   2007,
#   2006,
#   2005,
#   2020,
#   2018,
#   2017,
#   2017,
#   2016,
#   2020,
#   2017,
#   2013,
#   2017,
#   2013,
#   2013,
#   2016,
#   2015,
#   2019,
#   2018,
#   2018,
#   2019,
#   2021,
#   2017,
#   2015,
#   2011,
#   2016,
#   2015,
#   2015,
#   2013,
#   2008,
#   2019,
#   2008,
#   2013,
#   2016,
#   2018,
#   2011,
#   2010,
#   2016,
#   2013,
#   2016,
#   2015,
#   2013,
#   2020,
#   2015,
#   2011,
#   2015,
#   2019,
#   2010,
#   2015,
#   2013,
#   2017,
#   2016,
#   2019,
#   2009,
#   2019,
#   2014,
#   2011,
#   2016,
#   2010,
#   2010,
#   2013,
#   2015,
#   2012,
#   2010,
#   2016,
#   2017,
#   2017,
#   2015,
#   2016,
#   2016,
#   2009,
#   2013,
#   2020,
#   2012,
#   2018,
#   2014,
#   2018,
#   2018,
#   2014,
#   2013,
#   2013,
#   2008,
#   2016,
#   2010,
#   2011,
#   2012,
#   2012,
#   2011,
#   2018,
#   2016,
#   2012,
#   2006,
#   2016,
#   2015,
#   2014,
#   2018,
#   2017,
#   2018,
#   2006,
#   2016,
#   2016,
#   2010,
#   2009,
#   2020,
#   2008,
#   2014,
#   2012,
#   2019,
#   2014,
#   2012,
#   2006,
#   2013,
#   2018,
#   2018,
#   2005,
#   2011,
#   2019,
#   2013,
#   2013,
#   2010,
#   2013,
#   2014,
#   2013,
#   2011,
#   2018,
#   2011,
#   2007,
#   2012,
#   2012,
#   2008,
#   2009,
#   2014,
#   2011,
#   2018,
#   2013,
#   2013,
#   2017,
#   2014,
#   2014,
#   2013,
#   2009,
#   2017,
#   2013,
#   2010,
#   None,
#   1966,
#   2006,
#   2008,
#   2008,
#   2009,
#   2010,
#   2005,
#   1994,
#   2007,
#   2017,
#   2009,
#   2012,
#   2014,
#   2005,
#   2008,
#   2008,
#   2005,
#   2018,
#   2012,
#   2006,
#   2012,
#   2004,
#   2013,
#   2000,
#   2006,
#   2002,
#   2015,
#   1999,
#   2000,
#   2013,
#   2012,
#   2006,
#   2004,
#   2006,
#   2005,
#   2009,
#   2005,
#   2003,
#   2001,
#   2014,
#   2002,
#   2006,
#   2004,
#   2012,
#   1982,
#   1982,
#   2010],
#  'Country_of_Origin': ['Japan',
#   'Germany',
#   'Germany',
#   'Germany',
#   'Germany',
#   'United States',
#   'United Kingdom',
#   'Germany',
#   'Italy',
#   'United States',
#   'United Kingdom',
#   'United Kingdom',
#   'Germany',
#   'Italy',
#   'United Kingdom',
#   'United Kingdom',
#   'United States',
#   'Italy',
#   'Italy',
#   'United States',
#   'United Kingdom',
#   'Italy',
#   'Germany',
#   'Germany',
#   'United States',
#   'Germany',
#   'Germany',
#   'Germany',
#   'Germany',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Germany',
#   'United States',
#   'United States',
#   'United Kingdom',
#   'United Kingdom',
#   'United States',
#   'United Kingdom',
#   'Japan',
#   'Germany',
#   'United Kingdom',
#   'Germany',
#   'Italy',
#   'Japan',
#   'Germany',
#   'Germany',
#   'Germany',
#   'Germany',
#   'United States',
#   'United States',
#   'Germany',
#   'Italy',
#   'Germany',
#   'Germany',
#   'Japan',
#   'Japan',
#   'Germany',
#   'Japan',
#   'United States',
#   'Germany',
#   'Japan',
#   'Germany',
#   'United States',
#   'United Kingdom',
#   'Japan',
#   'Germany',
#   'Germany',
#   'United States',
#   'Germany',
#   'United States',
#   'United States',
#   'Italy',
#   'United Kingdom',
#   'United States',
#   'United Kingdom',
#   'United States',
#   'United States',
#   'Germany',
#   'United States',
#   'United States',
#   'United Kingdom',
#   'Germany',
#   'Germany',
#   'Germany',
#   'United States',
#   'Germany',
#   'Germany',
#   'Germany',
#   'United States',
#   'Germany',
#   'United States',
#   'Italy',
#   'Germany',
#   'United States',
#   'Germany',
#   'United States',
#   'Germany',
#   'Germany',
#   'United Kingdom',
#   'Germany',
#   'Germany',
#   'Germany',
#   'Japan',
#   'Germany',
#   'Germany',
#   'Japan',
#   'United Kingdom',
#   None,
#   'Germany',
#   'United Kingdom',
#   'Germany',
#   'Italy',
#   'United States',
#   'United States',
#   'United Kingdom',
#   'Germany',
#   'Germany',
#   'Germany',
#   'United Kingdom',
#   'United Kingdom',
#   'Germany',
#   None,
#   'United States',
#   'United Kingdom',
#   'Germany',
#   'Germany',
#   'United States',
#   'Germany',
#   'United Kingdom',
#   'Japan',
#   'Germany',
#   'Japan',
#   'Germany',
#   'Germany',
#   'Italy',
#   'United Kingdom',
#   'United Kingdom',
#   'Italy',
#   'United States',
#   'Japan',
#   'Germany',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Germany',
#   'United Kingdom',
#   'United States',
#   'United Kingdom',
#   'Japan',
#   'Germany',
#   'South Korea',
#   'Japan',
#   'United Kingdom',
#   'Japan',
#   'Germany',
#   'Japan',
#   'United States',
#   'Japan',
#   'Japan',
#   'United States',
#   'Germany',
#   None,
#   'Germany',
#   'Germany',
#   'Germany',
#   'Japan',
#   'Japan',
#   'Japan',
#   'Japan',
#   'Germany',
#   'Germany',
#   'Japan',
#   'United Kingdom',
#   'Germany',
#   'United Kingdom',
#   'United Kingdom',
#   'Japan',
#   'United States',
#   'United States',
#   'Germany',
#   'Germany',
#   'Japan',
#   'Japan',
#   'Japan',
#   'Germany',
#   'United States',
#   'United States',
#   'South Korea'],
#  'Engine_type': ['V8 DOHC',
#   'V8 DOHC',
#   'V8 DOHC',
#   'V12 DOHC Twin Turbo',
#   'V8 DOHC',
#   'DOHC twin-turbocharged V8, 3 electric motors',
#   'V8 DOHC Twin Turbo',
#   'twin-turbocharged flat-6',
#   'Mercedes-Benz AMG V12 60°',
#   'V10',
#   'V8 Twin Turbo',
#   'twin-turbocharged V8',
#   'V8 gasoline engine and two electric motors',
#   'V10 DOHC',
#   'Twin Turbo V8, DOHC, dual VVT 32v + Electric motor (176 hp/260 Nm)',
#   'Twin Turbo V8, DOHC, dual VVT 32v + Electric motor (176 hp/260 Nm)',
#   'V10',
#   'V8 twin turbo',
#   'twin turbo V8',
#   'V8 pushrod Supercharged',
#   'twin-turbocharged V8',
#   'Naturally aspirated V10',
#   'B6 twin turbo 24 valve DOHC',
#   'V8 Twin Turbo',
#   'GM LT4 6.2L Supercharged',
#   'flat 6 n/a',
#   'Boxer 6, twin turbo',
#   'flat-6',
#   'flat-6',
#   'OHV 20-valve V-10',
#   'V-8 supercharged',
#   'Supercharged Predator V8',
#   'V-10, 2 valves per cylinder',
#   'Naturally Aspirated V10',
#   'Direct injection V10',
#   'Supercharged LT4 V8',
#   'LS7 V8',
#   'V8 twin turbo',
#   'V8 twin turbo',
#   'Naturally Aspirated V10',
#   'Twin Turbo V8',
#   'tt v6',
#   'V8',
#   'V8 Twin Turbo',
#   'M178 TwinTurbo V8',
#   'V12, 48 valve',
#   'tt v6',
#   'Flat 6, Biturbo, DI, DOHC, 24 valves, DVVT, VVL',
#   'Flat 6, twin turbo',
#   'M178 TwinTurbo V8',
#   '6-cylinder-boxer, biturbo',
#   'LT1 V8',
#   'Flat-Crank Naturally Aspirated V8',
#   'Naturally Aspirated flat-six',
#   'V8',
#   'V8, Twin-turbo, DI, DOHC, 32 valves, DVVT',
#   'straight six, twin turbo',
#   'V6 DOHC 24V twinturbo',
#   'TwinTurbo V6',
#   'V10 n/a',
#   'V10',
#   'Naturally Aspirated V10',
#   'twin turbo Flat 6',
#   'V6',
#   'B6, 24 valve',
#   'Naturally Aspirated Flat Plane V8',
#   'V8, supercharged, DI, 32 valves, DOHC',
#   'V6 DOHC Twin Turbo',
#   'Flat 6, 24 valve',
#   'Inline 6 turbo',
#   'V8 LT1',
#   'flat six turbo with direct injection',
#   'V8 LS7',
#   'Naturally Aspirated LT2 V8',
#   'V12 6.3 litre',
#   '48 valve, twin-turbo, V12',
#   'LT1 V8',
#   'V8 DOHC Twin Turbo',
#   'V8 DOHC n/a',
#   'SuperCharged GM LT4 V8',
#   '10 cylinders V 90°, Naturally-aspirated,  DOHC, 4 Valves per Cyl, FSI',
#   'V8 32V DOHC Supercharged (2.3l  TVS positive displacement blower)',
#   'V-8 supercharged',
#   'V8 Supercharged',
#   'V8',
#   'Naturally aspirated V8',
#   'Boxer 6, n/a, DOHC, 24v',
#   'LSA V8',
#   'flat6 24V n/a',
#   'V8 twin turbo 32 valve DOHC',
#   'Flat 6 twin turbo',
#   'Naturally Aspirated V8',
#   'B6, 24 valve',
#   'TwinTurbo GM LF4 V6',
#   'Twin Turbo V6',
#   'straight six, twin turbo',
#   'Dual Motor Electric',
#   'V8, biturbo, DI, 32 valves, DOHC, Valvetronic',
#   'Electric motors',
#   'twin turbo B6',
#   '5 Cylinder Turbo',
#   'twin-turbo V12',
#   'flat six turbo with direct injection',
#   'V10 40v DOHC FSI',
#   'V8 twin turbo 32 valve DOHC',
#   'V6 twinturbo',
#   'V8 Twin Turbo',
#   'V8, DOHC, twin turbo (twin scrolls)',
#   'inline 6 turbo',
#   'V12 48 valve DOHC',
#   'V12, 48v',
#   'V8',
#   'Supercharged 90º V8, n/a, DOHC, 32v',
#   'Twin Turbo I6',
#   'V8 Twin Turbo',
#   'V8, 16v',
#   'V8',
#   'V8 Twin Turbo',
#   '6-cylinder-boxer',
#   '6-cylinder-boxer',
#   'flat 6',
#   'AM28 n/a 60º V12, DOHC, 48v',
#   'Supercharged V8',
#   'V8 Biturbo',
#   'DOHC V6 VVT-I',
#   'Hellcat Hemi V8 with Demon supercharger',
#   'V8, supercharged',
#   'V8, 32v',
#   'V8 32v FSI, DOHC, 4 Valves per Cyl',
#   'Naturally Aspirated V8',
#   'Flat-6 n/a',
#   '48 valve V12',
#   'v8',
#   'inline6 24V DOHV Turbo',
#   'V8 32 valve DOHC',
#   'V8',
#   'Naturally aspirated V8, DOHC, 32v',
#   'Twin Turbo V6',
#   'V8 Twin Turbo',
#   'V8 Twin Turbo',
#   'Turbo 4-cylinder, DOHC, 16v',
#   'V8 charger',
#   'Inline 4, turbo, DI, DOHC, 16 valves, VTEC, Dual-VTC',
#   'Electric motor and Inline 3 turbo 12 valve DOHC',
#   'V8',
#   '427 V8',
#   'Ford Big-Block FE 427',
#   'V8, Supercharged, 32v',
#   'V8',
#   'Flat 6 direct fuel injection',
#   'V8',
#   'V8',
#   '4 cyl',
#   'Inline 6, Twin Turbo, 24v',
#   'Inline 6, Twin Turbo, 24v',
#   '3.3 Litre V6 Twin Turbo',
#   'V6 24V DOHC n/a',
#   'W12, Twin-Turbo, 48v',
#   'Turbo Boxer-4, DOHC, 16v',
#   'B6',
#   'inline 4 turbo 16V DOHC',
#   'Inline 4, Turbocharged',
#   'Inline 4, Turbocharged',
#   'Inline 4, n/a, DI, 16 valves, DOHC, DVVT',
#   'Electric Motor',
#   'twin turbo R6',
#   'I4 16V DI Turbo',
#   'B6, 24 valve',
#   '4-cylinder-in-line, turbo',
#   'Flat 6 24 valve',
#   '4cyl Turbo',
#   'Renesis R2',
#   'I-4',
#   'Inline 4, 16v',
#   'Inline 6, 24v',
#   'I4, turbocharged with VCT',
#   'Flat-4',
#   '4cyl charger',
#   'B6, 24 valve',
#   'Inline 4, Turbocharged, 16v',
#   'V8',
#   'DOHC 16-valve 4-cylinder engine with variable valve timing (VVT)',
#   'PushRod 16-Valve LS6 V8',
#   'V8 n/a',
#   'Boxer 6, 24v',
#   'Straight 6  4 valves / cylinder, DOHC, Variable Valve Timing',
#   'V6',
#   'Inline 4, 16v',
#   'V6',
#   'boxer/6',
#   '305ci V8',
#   '5.0 V8',
#   'L4 DOHC 16V CVVT'],
#  'Displacement': [3.4,
#   3.4,
#   3.4,
#   5.5,
#   3.0,
#   2.9,
#   4.0,
#   3.8,
#   6.0,
#   8.4,
#   4.0,
#   4.0,
#   4.6,
#   5.2,
#   3.8,
#   3.8,
#   8.4,
#   3.9,
#   3.9,
#   6.2,
#   3.8,
#   5.2,
#   3.7,
#   4.0,
#   6.2,
#   4.0,
#   3.8,
#   4.0,
#   4.0,
#   8.4,
#   6.2,
#   5.2,
#   8.4,
#   8.4,
#   5.2,
#   6.2,
#   7.0,
#   3.8,
#   3.8,
#   8.4,
#   3.8,
#   3.8,
#   6.2,
#   3.8,
#   4.0,
#   6.5,
#   3.8,
#   3.0,
#   3.6,
#   4.0,
#   3.8,
#   6.2,
#   5.2,
#   4.0,
#   4.5,
#   4.0,
#   3.0,
#   3.8,
#   3.5,
#   5.2,
#   4.8,
#   8.4,
#   3.0,
#   3.8,
#   3.8,
#   5.2,
#   5.0,
#   3.8,
#   3.8,
#   3.0,
#   6.2,
#   3.8,
#   7.0,
#   6.2,
#   6.3,
#   5.2,
#   6.2,
#   4.0,
#   5.0,
#   6.2,
#   5.2,
#   5.8,
#   6.2,
#   5.0,
#   6.2,
#   6.2,
#   3.8,
#   6.2,
#   3.8,
#   4.4,
#   3.0,
#   5.0,
#   3.6,
#   3.6,
#   2.9,
#   3.0,
#   0.0,
#   4.4,
#   0.0,
#   3.6,
#   2.5,
#   5.2,
#   3.8,
#   5.2,
#   4.0,
#   3.8,
#   4.0,
#   4.4,
#   3.0,
#   5.9,
#   6.0,
#   4.2,
#   5.0,
#   3.0,
#   4.0,
#   7.0,
#   5.0,
#   4.0,
#   3.4,
#   3.4,
#   3.4,
#   5.9,
#   5.0,
#   5.5,
#   3.5,
#   6.2,
#   5.0,
#   4.0,
#   4.2,
#   5.0,
#   3.5,
#   6.0,
#   5.0,
#   3.0,
#   5.0,
#   6.2,
#   6.2,
#   2.9,
#   4.0,
#   4.0,
#   1.8,
#   6.2,
#   2.0,
#   1.5,
#   5.4,
#   7.0,
#   7.0,
#   5.4,
#   5.4,
#   3.6,
#   5.0,
#   6.2,
#   1.8,
#   3.0,
#   3.0,
#   3.3,
#   3.7,
#   6.0,
#   2.5,
#   3.4,
#   2.0,
#   2.0,
#   2.0,
#   2.0,
#   0.0,
#   3.0,
#   2.0,
#   3.8,
#   2.0,
#   2.7,
#   2.3,
#   1.3,
#   2.0,
#   2.0,
#   3.0,
#   1.6,
#   2.0,
#   1.6,
#   3.6,
#   1.6,
#   4.3,
#   2.0,
#   5.7,
#   5.7,
#   3.6,
#   3.0,
#   3.2,
#   2.0,
#   3.2,
#   3.4,
#   5.0,
#   5.0,
#   2.0],
#  'Transmission': ['6 speed Sequential',
#   '6 speed Sequential',
#   '6 speed Sequential',
#   '5 speed Sequential',
#   '6 speed Sequential',
#   '7-speed sequential automatic',
#   '7-speed daul clutch',
#   '7 speed dual clutch automatic (PDK)',
#   '7-speed with electronic mechanical differential',
#   'Tremec TR6060 six-speed manual transmission',
#   '7 speed dual clutch automatic',
#   '7 Speed SSG',
#   '7-speed-PDK',
#   '7 speed dual clutch automatic',
#   'Paddle Operated 7 speed Automatic',
#   'Paddle Operated 7 speed Automatic',
#   'Tremec TR6060 six-speed manual transmission',
#   '7 speed automatic',
#   '7 speed dual clutch automatic',
#   '7 speed manual and 8 speed automatic',
#   '7 speed dual clutch automatic',
#   '7 speed dual clutch automatic',
#   '8 speed dual-clutch automatic (PDK)',
#   '7-speed SPEEDSHIFT (dual-clutch)',
#   '7 Speed Manual/8 Speed Automatic Paddle Shift',
#   '6 speed maual',
#   '7 speed PDK',
#   'seven-speed PDK dual-clutch',
#   'seven-speed PDK dual-clutch',
#   '6-Speed Tremec 6060',
#   '6',
#   '7-speed DCT',
#   '6',
#   '6-Speed Manual',
#   '7-speed S-tronic',
#   '6-Speed Manual',
#   '6',
#   '7 speed dual clutch',
#   '7 speed SSG',
#   '6-Speed Manual',
#   '7- speed Seamless Shift dual clutch Gearbox (SSG)',
#   '6 speed dual clutch',
#   '7-speed-MCT',
#   '7 speed dual clutch automatic',
#   '7-Speed AMG SpeedShift MCT',
#   '7 speed ISR',
#   '6 speed dual clutch',
#   '8 speed dual-clutch automatic (PDK) or 7 speed manual',
#   '6 speed manual',
#   '7-Speed AMG SpeedShift MCT',
#   '7-speed-PDK',
#   '7-speed manual 8-speed auto',
#   '6-Speed Manual',
#   '6-speed manual',
#   '7 speed dual clutch',
#   '9 speed automatic',
#   '7speed DCT or 6 speed manual',
#   '6 speed dual clutch transaxle',
#   '9-Speed DCT',
#   '6 speed R-tronic',
#   '6 speed sequential',
#   '6-Speed Manual',
#   '7-speed manual or 7-speed dual clutch',
#   '6-Speed DCT',
#   '6 speed manual',
#   '6-Speed Manual',
#   '8 speed automatic',
#   '6-Speed DCT',
#   'Manual six-speed',
#   'DCT',
#   '6 speed manual/8 speed automatic',
#   '6speed manual or PDK',
#   '6-Speed Tremec',
#   '8 Speed DCT',
#   None,
#   'Rear mid-mounted ZF 8-speed automatic',
#   '6-Speed Manual/7-Speed Manual',
#   '8-speed ZF automatic',
#   '6 speed manual, 10-speed auto',
#   '8L90 8-Speed AutoMatic',
#   '7 Speed S-Tronic Automatic or Optional 6-Speed manual',
#   '6 speed manual',
#   '6',
#   '8 speed automatic',
#   '7 speed dual clutch transaxle',
#   '7-MCT',
#   '7 speed manual / 7 PDK',
#   '6-Speed Manual',
#   '7 speed PDK or 7 speed manual',
#   '8 speed ZF 8HP',
#   '7 speed dual-clutch automatic (PDK)',
#   '6-Speed Manual',
#   '6 speed manual',
#   '6-Speed Manual/8-Speed Automatic',
#   '8-speed automatic or 6 speed manual',
#   '7speed DCT or 6 speed manual',
#   'Single Speed',
#   '8 speed automatic',
#   'single speed',
#   '6 speed',
#   '7 Speed Dual Clutch',
#   '8-speed auto ZF',
#   '7 speed PDK',
#   '6 speed manual or 6 speed R-Tronic',
#   '8 speed automatic',
#   '6 speed double clutch',
#   '7-Speed Automatic',
#   '7 speed dct',
#   '8 speed automatic (ZF)',
#   '8 speed automatic',
#   '8 speed auto',
#   '6 speed',
#   'QuickShift 8 speed automatic',
#   '6-speed manual or 7-speed dual-clutch',
#   '8-speed ZF 8HP automatic',
#   '6 speed manual',
#   '6-Speed',
#   '8 speed dual clutch automatic',
#   '6-speed-manual, 7-speed-PDK',
#   '6-speed-manual, 7-speed-PDK',
#   '7-speed PDK',
#   'Sportshift III 7 speed sequential',
#   '8-speed Quick Shift',
#   '7 gears automatic',
#   '6 speed manny',
#   '8 speed auto only',
#   '6 speed automatic',
#   '6 speed. manual  or 7 speed double clutch (DKG)',
#   '7 speed S-tronic',
#   '6-Speed Manual',
#   '6 speed manual or 7 speed PDK',
#   '6 speed manual',
#   '8 speed auto',
#   '6 speed manual',
#   '10 speed dual-clutch automatic',
#   '7-speed multi-clutch automatic (MCT)',
#   'Speedshift MCT 7 speed',
#   'Automatic Transmission',
#   '8 speed auto',
#   '8 speed auto',
#   'TCT twin dry clutch',
#   '6 speed automatic',
#   '6 speed manual',
#   '6 speed automatic',
#   '6',
#   '3-Speed',
#   '4 Speed Manual',
#   '6',
#   '6',
#   '6 speed manual  or 7speed dual clutch (PDK)',
#   '6 speed automatic',
#   '6',
#   '6-Speed',
#   '6',
#   '6 speed manual',
#   '8 Speed Transmission',
#   '6 Speed Manual',
#   '8 speed ZF transmission',
#   '6-speed manual',
#   '6 speed',
#   '5 speed manual',
#   '5',
#   '6',
#   '6 speed manual',
#   None,
#   '6 speed',
#   '6 speed manual',
#   '6 speed manual',
#   '6-speed-manual, 6-speed-DSG',
#   '5 speed manual',
#   '6',
#   '6 speed',
#   '6-Speed Manual',
#   '6 speed',
#   '5',
#   '6 speed manual with torque vectoring',
#   '6-speed MT or 6-speed AT',
#   '6',
#   '6 speed manual or Tiptronic',
#   '6 speed manual',
#   '6 speed manual',
#   '6 manual',
#   '6 Speed Manaual',
#   '6',
#   '6',
#   '6 speed Manual',
#   '6 speed',
#   '6',
#   '6',
#   '6-speed-manual / 7-speed-PDK',
#   '5',
#   '5',
#   '5 Manual'],
#  'Engine_Layout': ['middle engine',
#   'middle engine',
#   'middle engine',
#   'middle engine',
#   'middle engine',
#   'middle engine',
#   'middle engine',
#   'rear engine',
#   'middle engine',
#   'front engine',
#   'middle engine',
#   'middle engine',
#   'middle engine',
#   'middle engine',
#   'middle engine',
#   'middle engine',
#   'front engine',
#   'middle engine',
#   'middle engine',
#   'front engine',
#   'middle engine',
#   'middle engine',
#   'rear engine',
#   'front engine',
#   'front engine',
#   'rear engine',
#   'rear engine',
#   'rear engine',
#   'rear engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'middle engine',
#   'front engine',
#   'front engine',
#   'middle engine',
#   'middle engine',
#   'front engine',
#   'middle engine',
#   'front engine',
#   'front engine',
#   'middle engine',
#   'front engine',
#   'middle engine',
#   'front engine',
#   'rear engine',
#   'rear engine',
#   'front engine',
#   'rear engine',
#   'front engine',
#   'front engine',
#   'middle engine',
#   'middle engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'middle engine',
#   'middle engine',
#   'front engine',
#   'front engine',
#   'rear engine',
#   'front engine',
#   'rear engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'middle engine',
#   'front engine',
#   'front engine',
#   'rear engine',
#   'front engine',
#   'middle engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'middle engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'rear engine',
#   'front engine',
#   'rear engine',
#   'front engine',
#   'rear engine',
#   'front engine',
#   'rear engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'rear engine',
#   'front engine',
#   'front engine',
#   'rear engine',
#   'front engine',
#   'front engine',
#   'rear engine',
#   'middle engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'middle engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'middle engine',
#   'middle engine',
#   'middle engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'middle engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'middle engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'middle engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'rear engine',
#   'front engine',
#   'front engine',
#   'middle engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'rear engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'rear engine',
#   'front engine',
#   'front engine',
#   'rear engine',
#   'front engine',
#   'middle engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'rear engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'front engine',
#   'rear engine',
#   'front engine',
#   'middle engine',
#   'front engine',
#   'middle engine',
#   'middle engine',
#   'front engine',
#   'front engine',
#   'front engine'],
#  'Drivetrain': ['rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'all wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'all wheel drive',
#   'all wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'all wheel drive',
#   'all wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'all wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'all wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'all wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'all wheel drive',
#   'all wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'all wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'all wheel drive',
#   'rear wheel drive',
#   'all wheel drive',
#   'all wheel drive',
#   'all wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'all wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'all wheel drive',
#   'all wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'all wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'all wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'all wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'all wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'all wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'all wheel drive',
#   'all wheel drive',
#   'all wheel drive',
#   'all wheel drive',
#   'all wheel drive',
#   'rear wheel drive',
#   'all wheel drive',
#   'all wheel drive',
#   'all wheel drive',
#   'all wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'all wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'all wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'all wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'all wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'all wheel drive',
#   'all wheel drive',
#   'all wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'front wheel drive',
#   'all wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'all wheel drive',
#   'all wheel drive',
#   'rear wheel drive',
#   'all wheel drive',
#   'front wheel drive',
#   'all wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'front wheel drive',
#   'rear wheel drive',
#   'front wheel drive',
#   'rear wheel drive',
#   'front wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'front wheel drive',
#   'rear wheel drive',
#   'front wheel drive',
#   'rear wheel drive',
#   'front wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'front wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'rear wheel drive',
#   'front wheel drive']}

# %%
moreRecords = pd.DataFrame.from_dict(additionaldict)

moreRecords
# Out:
#         Car_type    Year Country_of_Origin          Engine_type  Displacement  \
# 0          Coupe  2008.0             Japan              V8 DOHC           3.4
# 1          Coupe  2007.0           Germany              V8 DOHC           3.4
# 2          Coupe  2007.0           Germany              V8 DOHC           3.4
# 3          Coupe  2006.0           Germany  V12 DOHC Twin Turbo           5.5
# 4          Coupe  2005.0           Germany              V8 DOHC           3.0
# ..           ...     ...               ...                  ...           ...
# 188        Coupe  2004.0             Japan                   V6           3.2
# 189  Convertible  2012.0           Germany              boxer/6           3.4
# 190        Coupe  1982.0     United States             305ci V8           5.0
# 191        Coupe  1982.0     United States               5.0 V8           5.0
# 192      Compact  2010.0       South Korea     L4 DOHC 16V CVVT           2.0
#
#                      Transmission  Engine_Layout         Drivetrain
# 0              6 speed Sequential  middle engine   rear wheel drive
# 1              6 speed Sequential  middle engine   rear wheel drive
# 2              6 speed Sequential  middle engine   rear wheel drive
# 3              5 speed Sequential  middle engine   rear wheel drive
# 4              6 speed Sequential  middle engine   rear wheel drive
# ..                            ...            ...                ...
# 188                             6  middle engine   rear wheel drive
# 189  6-speed-manual / 7-speed-PDK  middle engine   rear wheel drive
# 190                             5   front engine   rear wheel drive
# 191                             5   front engine   rear wheel drive
# 192                      5 Manual   front engine  front wheel drive
#
# [193 rows x 8 columns]

# %%
df = Currframe.copy()

df = df.join(moreRecords)

df
# Out:
#                         Name  \
# 0              Acura ARX-01b
# 1    Porsche RS Spyder (Evo)
# 2              Acura ARX-01a
# 3               Audi R10 TDI
# 4          Porsche RS Spyder
# ..                       ...
# 188     Honda NSX (facelift)
# 189  Porsche Boxster S (981)
# 190     Chevrolet Camaro Z28
# 191          Ford Mustang GT
# 192       Kia Soul Sport 2.0
#
#                                                CarLink    Time   PS  \
# 0         https://fastestlaps.com/models/acura-arx-01b   70.10  558
# 1     https://fastestlaps.com/models/porsche-rs-spyder   70.35  510
# 2         https://fastestlaps.com/models/acura-arx-01a   70.91  558
# 3          https://fastestlaps.com/models/audi-r10-tdi   71.17  659
# 4    https://fastestlaps.com/models/porsche-rs-spyd...   74.03  487
# ..                                                 ...     ...  ...
# 188           https://fastestlaps.com/models/honda-nsx  117.00  290
# 189  https://fastestlaps.com/models/porsche-boxster...  119.01  315
# 190  https://fastestlaps.com/models/chevrolet-camar...  125.80  193
# 191  https://fastestlaps.com/models/ford-mustang-gt...  129.90  159
# 192  https://fastestlaps.com/models/kia-soul-sport-2-0  132.67  144
#
#      Weight_KG     Car_type    Year Country_of_Origin          Engine_type  \
# 0          825        Coupe  2008.0             Japan              V8 DOHC
# 1          775        Coupe  2007.0           Germany              V8 DOHC
# 2          825        Coupe  2007.0           Germany              V8 DOHC
# 3          925        Coupe  2006.0           Germany  V12 DOHC Twin Turbo
# 4          775        Coupe  2005.0           Germany              V8 DOHC
# ..         ...          ...     ...               ...                  ...
# 188       1368        Coupe  2004.0             Japan                   V6
# 189       1400  Convertible  2012.0           Germany              boxer/6
# 190       1448        Coupe  1982.0     United States             305ci V8
# 191       1422        Coupe  1982.0     United States               5.0 V8
# 192       1320      Compact  2010.0       South Korea     L4 DOHC 16V CVVT
#
#      Displacement                  Transmission  Engine_Layout  \
# 0             3.4            6 speed Sequential  middle engine
# 1             3.4            6 speed Sequential  middle engine
# 2             3.4            6 speed Sequential  middle engine
# 3             5.5            5 speed Sequential  middle engine
# 4             3.0            6 speed Sequential  middle engine
# ..            ...                           ...            ...
# 188           3.2                             6  middle engine
# 189           3.4  6-speed-manual / 7-speed-PDK  middle engine
# 190           5.0                             5   front engine
# 191           5.0                             5   front engine
# 192           2.0                      5 Manual   front engine
#
#             Drivetrain
# 0     rear wheel drive
# 1     rear wheel drive
# 2     rear wheel drive
# 3     rear wheel drive
# 4     rear wheel drive
# ..                 ...
# 188   rear wheel drive
# 189   rear wheel drive
# 190   rear wheel drive
# 191   rear wheel drive
# 192  front wheel drive
#
# [193 rows x 13 columns]

# %%
df.describe()
# Out:
#              Time           PS    Weight_KG         Year  Displacement
# count  193.000000   193.000000   193.000000   192.000000    193.000000
# mean   100.200415   494.502591  1581.642487  2011.750000      4.267876
# std      8.743107   167.569890   268.329383     6.645866      1.646304
# min     70.100000   144.000000   775.000000  1966.000000      0.000000
# 25%     95.560000   400.000000  1435.000000  2009.000000      3.400000
# 50%     99.800000   510.000000  1593.000000  2013.000000      4.000000
# 75%    104.300000   600.000000  1748.000000  2016.000000      5.200000
# max    132.670000  1267.000000  2336.000000  2021.000000      8.400000

# %%
df.isna().sum()
# Out:
# Name                 0
# CarLink              0
# Time                 0
# PS                   0
# Weight_KG            0
# Car_type             0
# Year                 1
# Country_of_Origin    3
# Engine_type          0
# Displacement         0
# Transmission         2
# Engine_Layout        0
# Drivetrain           0
# dtype: int64

# %%
df.dtypes
# Out:
# Name                  object
# CarLink               object
# Time                 float64
# PS                     int64
# Weight_KG              int64
# Car_type              object
# Year                 float64
# Country_of_Origin     object
# Engine_type           object
# Displacement         float64
# Transmission          object
# Engine_Layout         object
# Drivetrain            object
# dtype: object

# %%
df.dropna(inplace = True)

df
# Out:
#                         Name  \
# 0              Acura ARX-01b
# 1    Porsche RS Spyder (Evo)
# 2              Acura ARX-01a
# 3               Audi R10 TDI
# 4          Porsche RS Spyder
# ..                       ...
# 188     Honda NSX (facelift)
# 189  Porsche Boxster S (981)
# 190     Chevrolet Camaro Z28
# 191          Ford Mustang GT
# 192       Kia Soul Sport 2.0
#
#                                                CarLink    Time   PS  \
# 0         https://fastestlaps.com/models/acura-arx-01b   70.10  558
# 1     https://fastestlaps.com/models/porsche-rs-spyder   70.35  510
# 2         https://fastestlaps.com/models/acura-arx-01a   70.91  558
# 3          https://fastestlaps.com/models/audi-r10-tdi   71.17  659
# 4    https://fastestlaps.com/models/porsche-rs-spyd...   74.03  487
# ..                                                 ...     ...  ...
# 188           https://fastestlaps.com/models/honda-nsx  117.00  290
# 189  https://fastestlaps.com/models/porsche-boxster...  119.01  315
# 190  https://fastestlaps.com/models/chevrolet-camar...  125.80  193
# 191  https://fastestlaps.com/models/ford-mustang-gt...  129.90  159
# 192  https://fastestlaps.com/models/kia-soul-sport-2-0  132.67  144
#
#      Weight_KG     Car_type    Year Country_of_Origin          Engine_type  \
# 0          825        Coupe  2008.0             Japan              V8 DOHC
# 1          775        Coupe  2007.0           Germany              V8 DOHC
# 2          825        Coupe  2007.0           Germany              V8 DOHC
# 3          925        Coupe  2006.0           Germany  V12 DOHC Twin Turbo
# 4          775        Coupe  2005.0           Germany              V8 DOHC
# ..         ...          ...     ...               ...                  ...
# 188       1368        Coupe  2004.0             Japan                   V6
# 189       1400  Convertible  2012.0           Germany              boxer/6
# 190       1448        Coupe  1982.0     United States             305ci V8
# 191       1422        Coupe  1982.0     United States               5.0 V8
# 192       1320      Compact  2010.0       South Korea     L4 DOHC 16V CVVT
#
#      Displacement                  Transmission  Engine_Layout  \
# 0             3.4            6 speed Sequential  middle engine
# 1             3.4            6 speed Sequential  middle engine
# 2             3.4            6 speed Sequential  middle engine
# 3             5.5            5 speed Sequential  middle engine
# 4             3.0            6 speed Sequential  middle engine
# ..            ...                           ...            ...
# 188           3.2                             6  middle engine
# 189           3.4  6-speed-manual / 7-speed-PDK  middle engine
# 190           5.0                             5   front engine
# 191           5.0                             5   front engine
# 192           2.0                      5 Manual   front engine
#
#             Drivetrain
# 0     rear wheel drive
# 1     rear wheel drive
# 2     rear wheel drive
# 3     rear wheel drive
# 4     rear wheel drive
# ..                 ...
# 188   rear wheel drive
# 189   rear wheel drive
# 190   rear wheel drive
# 191   rear wheel drive
# 192  front wheel drive
#
# [187 rows x 13 columns]

# %%
df.to_csv("LagunaSecaLapTimesMore.csv", index = False)
